# %%
! pip install python-openstacksdk
# Out:
# Requirement already satisfied: python-openstacksdk in c:\users\lenovo\anaconda3\lib\site-packages (0.5.2)
# Requirement already satisfied: openstacksdk in c:\users\lenovo\anaconda3\lib\site-packages (from python-openstacksdk) (0.103.0)
# Requirement already satisfied: jmespath>=0.9.0 in c:\users\lenovo\anaconda3\lib\site-packages (from openstacksdk->python-openstacksdk) (0.10.0)
# Requirement already satisfied: requestsexceptions>=1.2.0 in c:\users\lenovo\anaconda3\lib\site-packages (from openstacksdk->python-openstacksdk) (1.4.0)
# Requirement already satisfied: cryptography>=2.7 in c:\users\lenovo\anaconda3\lib\site-packages (from openstacksdk->python-openstacksdk) (37.0.1)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in c:\users\lenovo\anaconda3\lib\site-packages (from openstacksdk->python-openstacksdk) (5.11.1)
# Requirement already satisfied: netifaces>=0.10.4 in c:\users\lenovo\anaconda3\lib\site-packages (from openstacksdk->python-openstacksdk) (0.11.0)
# Requirement already satisfied: os-service-types>=1.7.0 in c:\users\lenovo\anaconda3\lib\site-packages (from openstacksdk->python-openstacksdk) (1.7.0)
# Requirement already satisfied: munch>=2.1.0 in c:\users\lenovo\anaconda3\lib\site-packages (from openstacksdk->python-openstacksdk) (2.5.0)
# Requirement already satisfied: PyYAML>=3.13 in c:\users\lenovo\anaconda3\lib\site-packages (from openstacksdk->python-openstacksdk) (6.0)
# Requirement already satisfied: decorator>=4.4.1 in c:\users\lenovo\anaconda3\lib\site-packages (from openstacksdk->python-openstacksdk) (5.1.1)
# Requirement already satisfied: iso8601>=0.1.11 in c:\users\lenovo\anaconda3\lib\site-packages (from openstacksdk->python-openstacksdk) (1.1.0)
# Requirement already satisfied: jsonpatch!=1.20,>=1.16 in c:\users\lenovo\anaconda3\lib\site-packages (from openstacksdk->python-openstacksdk) (1.32)
# Requirement already satisfied: appdirs>=1.3.0 in c:\users\lenovo\anaconda3\lib\site-packages (from openstacksdk->python-openstacksdk) (1.4.4)
# Requirement already satisfied: keystoneauth1>=3.18.0 in c:\users\lenovo\anaconda3\lib\site-packages (from openstacksdk->python-openstacksdk) (5.1.1)
# Requirement already satisfied: dogpile.cache>=0.6.5 in c:\users\lenovo\anaconda3\lib\site-packages (from openstacksdk->python-openstacksdk) (1.1.8)
# Requirement already satisfied: cffi>=1.12 in c:\users\lenovo\anaconda3\lib\site-packages (from cryptography>=2.7->openstacksdk->python-openstacksdk) (1.15.1)
# Requirement already satisfied: stevedore>=3.0.0 in c:\users\lenovo\anaconda3\lib\site-packages (from dogpile.cache>=0.6.5->openstacksdk->python-openstacksdk) (4.1.1)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\lenovo\anaconda3\lib\site-packages (from jsonpatch!=1.20,>=1.16->openstacksdk->python-openstacksdk) (2.3)
# Requirement already satisfied: six>=1.10.0 in c:\users\lenovo\anaconda3\lib\site-packages (from keystoneauth1>=3.18.0->openstacksdk->python-openstacksdk) (1.16.0)
# Requirement already satisfied: requests>=2.14.2 in c:\users\lenovo\anaconda3\lib\site-packages (from keystoneauth1>=3.18.0->openstacksdk->python-openstacksdk) (2.28.1)
# Requirement already satisfied: pycparser in c:\users\lenovo\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=2.7->openstacksdk->python-openstacksdk) (2.21)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lenovo\anaconda3\lib\site-packages (from requests>=2.14.2->keystoneauth1>=3.18.0->openstacksdk->python-openstacksdk) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lenovo\anaconda3\lib\site-packages (from requests>=2.14.2->keystoneauth1>=3.18.0->openstacksdk->python-openstacksdk) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\lenovo\anaconda3\lib\site-packages (from requests>=2.14.2->keystoneauth1>=3.18.0->openstacksdk->python-openstacksdk) (1.26.11)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\lenovo\anaconda3\lib\site-packages (from requests>=2.14.2->keystoneauth1>=3.18.0->openstacksdk->python-openstacksdk) (2.0.4)

# %%
! pip install openstacksdk
# Out:
# Requirement already satisfied: openstacksdk in c:\users\lenovo\anaconda3\lib\site-packages (0.103.0)
# Requirement already satisfied: appdirs>=1.3.0 in c:\users\lenovo\anaconda3\lib\site-packages (from openstacksdk) (1.4.4)
# Requirement already satisfied: decorator>=4.4.1 in c:\users\lenovo\anaconda3\lib\site-packages (from openstacksdk) (5.1.1)
# Requirement already satisfied: PyYAML>=3.13 in c:\users\lenovo\anaconda3\lib\site-packages (from openstacksdk) (6.0)
# Requirement already satisfied: os-service-types>=1.7.0 in c:\users\lenovo\anaconda3\lib\site-packages (from openstacksdk) (1.7.0)
# Requirement already satisfied: netifaces>=0.10.4 in c:\users\lenovo\anaconda3\lib\site-packages (from openstacksdk) (0.11.0)
# Requirement already satisfied: requestsexceptions>=1.2.0 in c:\users\lenovo\anaconda3\lib\site-packages (from openstacksdk) (1.4.0)
# Requirement already satisfied: jmespath>=0.9.0 in c:\users\lenovo\anaconda3\lib\site-packages (from openstacksdk) (0.10.0)
# Requirement already satisfied: dogpile.cache>=0.6.5 in c:\users\lenovo\anaconda3\lib\site-packages (from openstacksdk) (1.1.8)
# Requirement already satisfied: keystoneauth1>=3.18.0 in c:\users\lenovo\anaconda3\lib\site-packages (from openstacksdk) (5.1.1)
# Requirement already satisfied: munch>=2.1.0 in c:\users\lenovo\anaconda3\lib\site-packages (from openstacksdk) (2.5.0)
# Requirement already satisfied: iso8601>=0.1.11 in c:\users\lenovo\anaconda3\lib\site-packages (from openstacksdk) (1.1.0)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in c:\users\lenovo\anaconda3\lib\site-packages (from openstacksdk) (5.11.1)
# Requirement already satisfied: cryptography>=2.7 in c:\users\lenovo\anaconda3\lib\site-packages (from openstacksdk) (37.0.1)
# Requirement already satisfied: jsonpatch!=1.20,>=1.16 in c:\users\lenovo\anaconda3\lib\site-packages (from openstacksdk) (1.32)
# Requirement already satisfied: cffi>=1.12 in c:\users\lenovo\anaconda3\lib\site-packages (from cryptography>=2.7->openstacksdk) (1.15.1)
# Requirement already satisfied: stevedore>=3.0.0 in c:\users\lenovo\anaconda3\lib\site-packages (from dogpile.cache>=0.6.5->openstacksdk) (4.1.1)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\lenovo\anaconda3\lib\site-packages (from jsonpatch!=1.20,>=1.16->openstacksdk) (2.3)
# Requirement already satisfied: six>=1.10.0 in c:\users\lenovo\anaconda3\lib\site-packages (from keystoneauth1>=3.18.0->openstacksdk) (1.16.0)
# Requirement already satisfied: requests>=2.14.2 in c:\users\lenovo\anaconda3\lib\site-packages (from keystoneauth1>=3.18.0->openstacksdk) (2.28.1)
# Requirement already satisfied: pycparser in c:\users\lenovo\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=2.7->openstacksdk) (2.21)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lenovo\anaconda3\lib\site-packages (from requests>=2.14.2->keystoneauth1>=3.18.0->openstacksdk) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lenovo\anaconda3\lib\site-packages (from requests>=2.14.2->keystoneauth1>=3.18.0->openstacksdk) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\lenovo\anaconda3\lib\site-packages (from requests>=2.14.2->keystoneauth1>=3.18.0->openstacksdk) (1.26.11)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\lenovo\anaconda3\lib\site-packages (from requests>=2.14.2->keystoneauth1>=3.18.0->openstacksdk) (2.0.4)

# %%
import argparse
import os
import sys

import openstack

# %%
openstack.enable_logging(debug=True)

# %%
conn = openstack.connect(cloud='openstack',      
                         auth_url =  "http://controller:5000/v3/",
                         region_name = "RegionOne",
                         project_name = "admin",
                         username = "admin",
                         password = "ADMINS_PASS",
                         user_domain_name = "Default"
                         )

# %%
for server in conn.compute.servers():
    print(server.to_dict())
# Out:
# REQ: curl -g -i -X GET http://controller:5000/v3/ -H "Accept: application/json" -H "User-Agent: openstacksdk/0.103.0 keystoneauth1/5.1.1 python-requests/2.28.1 CPython/3.9.13"
# RESP: [200] Connection: Keep-Alive Content-Length: 250 Content-Type: application/json Date: Tue, 31 Jan 2023 12:14:50 GMT Keep-Alive: timeout=5, max=100 Server: Apache/2.4.41 (Ubuntu) Vary: X-Auth-Token x-openstack-request-id: req-fdf4cdf2-5d4e-4bb6-bb75-2d4b6d133ce1
# RESP BODY: {"version": {"id": "v3.14", "status": "stable", "updated": "2020-04-07T00:00:00Z", "links": [{"rel": "self", "href": "http://controller:5000/v3/"}], "media-types": [{"base": "application/json", "type": "application/vnd.openstack.identity-v3+json"}]}}
# GET call to http://controller:5000/v3/ used request id req-fdf4cdf2-5d4e-4bb6-bb75-2d4b6d133ce1
# Making authentication request to http://controller:5000/v3/auth/tokens
# Request returned failure status: 401
# ---------------------------------------------------------------------------
# Unauthorized                              Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15588\2717086158.py in <module>
# ----> 1 for server in conn.compute.servers():
#       2     print(server.to_dict())
#
# ~\anaconda3\lib\site-packages\openstack\service_description.py in __get__(self, instance, owner)
#      85             return self
#      86         if self.service_type not in instance._proxies:
# ---> 87             proxy = self._make_proxy(instance)
#      88             if not isinstance(proxy, _ServiceDisabledProxyShim):
#      89                 # The keystone proxy has a method called get_endpoint
#
# ~\anaconda3\lib\site-packages\openstack\service_description.py in _make_proxy(self, instance)
#     260             **version_kwargs
#     261         )
# --> 262         found_version = temp_adapter.get_api_major_version()
#     263         if found_version is None:
#     264             region_name = instance.config.get_region_name(self.service_type)
#
# ~\anaconda3\lib\site-packages\keystoneauth1\adapter.py in get_api_major_version(self, auth, **kwargs)
#     352             kwargs['endpoint_override'] = self.endpoint_override
#     353
# --> 354         return self.session.get_api_major_version(auth or self.auth, **kwargs)
#     355
#     356     def invalidate(self, auth=None):
#
# ~\anaconda3\lib\site-packages\keystoneauth1\session.py in get_api_major_version(self, auth, **kwargs)
#    1274         """
#    1275         auth = self._auth_required(auth, 'determine endpoint URL')
# -> 1276         return auth.get_api_major_version(self, **kwargs)
#    1277
#    1278     def get_all_version_data(self, auth=None, interface='public',
#
# ~\anaconda3\lib\site-packages\keystoneauth1\identity\base.py in get_api_major_version(self, session, service_type, interface, region_name, service_name, version, allow, allow_version_hack, skip_discovery, discover_versions, min_version, max_version, **kwargs)
#     498             skip_discovery=skip_discovery,
#     499             allow_version_hack=allow_version_hack, **kwargs)
# --> 500         data = get_endpoint_data(discover_versions=discover_versions)
#     501         if (not data or not data.api_version) and not discover_versions:
#     502             # It's possible that no version was requested and the endpoint
#
# ~\anaconda3\lib\site-packages\keystoneauth1\identity\base.py in get_endpoint_data(self, session, service_type, interface, region_name, service_name, allow, allow_version_hack, discover_versions, skip_discovery, min_version, max_version, endpoint_override, **kwargs)
#     269                 interface = 'public'
#     270
# --> 271             service_catalog = self.get_access(session).service_catalog
#     272             project_id = self.get_project_id(session)
#     273             # NOTE(mordred): service_catalog.url_data_for raises if it can't
#
# ~\anaconda3\lib\site-packages\keystoneauth1\identity\base.py in get_access(self, session, **kwargs)
#     132         with self._lock:
#     133             if self._needs_reauthenticate():
# --> 134                 self.auth_ref = self.get_auth_ref(session)
#     135
#     136         return self.auth_ref
#
# ~\anaconda3\lib\site-packages\keystoneauth1\identity\generic\base.py in get_auth_ref(self, session, **kwargs)
#     206             self._plugin = self._do_create_plugin(session)
#     207
# --> 208         return self._plugin.get_auth_ref(session, **kwargs)
#     209
#     210     def get_cache_id_elements(self, _implemented=False):
#
# ~\anaconda3\lib\site-packages\keystoneauth1\identity\v3\base.py in get_auth_ref(self, session, **kwargs)
#     186
#     187         _logger.debug('Making authentication request to %s', token_url)
# --> 188         resp = session.post(token_url, json=body, headers=headers,
#     189                             authenticated=False, log=False, **rkwargs)
#     190
#
# ~\anaconda3\lib\site-packages\keystoneauth1\session.py in post(self, url, **kwargs)
#    1147
#    1148         """
# -> 1149         return self.request(url, 'POST', **kwargs)
#    1150
#    1151     def put(self, url, **kwargs):
#
# ~\anaconda3\lib\site-packages\keystoneauth1\session.py in request(self, url, method, json, original_ip, user_agent, redirect, authenticated, endpoint_filter, auth, requests_auth, raise_exc, allow_reauth, log, endpoint_override, connect_retries, logger, allow, client_name, client_version, microversion, microversion_service_type, status_code_retries, retriable_status_codes, rate_semaphore, global_request_id, connect_retry_delay, status_code_retry_delay, **kwargs)
#     984             logger.debug('Request returned failure status: %s',
#     985                          resp.status_code)
# --> 986             raise exceptions.from_response(resp, method, url)
#     987
#     988         if self._collect_timing:
#
# Unauthorized: The request you have made requires authentication. (HTTP 401) (Request-ID: req-5895d537-b6f0-4732-b4da-796627b1a0f8)

# %%
for image in conn.compute.images():
    print(image.to_dict())
# Out:
# Making authentication request to http://controller:5000/v3/auth/tokens
# Request returned failure status: 401
# ---------------------------------------------------------------------------
# Unauthorized                              Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15588\761349445.py in <module>
# ----> 1 for image in conn.compute.images():
#       2     print(image.to_dict())
#
# ~\anaconda3\lib\site-packages\openstack\service_description.py in __get__(self, instance, owner)
#      85             return self
#      86         if self.service_type not in instance._proxies:
# ---> 87             proxy = self._make_proxy(instance)
#      88             if not isinstance(proxy, _ServiceDisabledProxyShim):
#      89                 # The keystone proxy has a method called get_endpoint
#
# ~\anaconda3\lib\site-packages\openstack\service_description.py in _make_proxy(self, instance)
#     260             **version_kwargs
#     261         )
# --> 262         found_version = temp_adapter.get_api_major_version()
#     263         if found_version is None:
#     264             region_name = instance.config.get_region_name(self.service_type)
#
# ~\anaconda3\lib\site-packages\keystoneauth1\adapter.py in get_api_major_version(self, auth, **kwargs)
#     352             kwargs['endpoint_override'] = self.endpoint_override
#     353
# --> 354         return self.session.get_api_major_version(auth or self.auth, **kwargs)
#     355
#     356     def invalidate(self, auth=None):
#
# ~\anaconda3\lib\site-packages\keystoneauth1\session.py in get_api_major_version(self, auth, **kwargs)
#    1274         """
#    1275         auth = self._auth_required(auth, 'determine endpoint URL')
# -> 1276         return auth.get_api_major_version(self, **kwargs)
#    1277
#    1278     def get_all_version_data(self, auth=None, interface='public',
#
# ~\anaconda3\lib\site-packages\keystoneauth1\identity\base.py in get_api_major_version(self, session, service_type, interface, region_name, service_name, version, allow, allow_version_hack, skip_discovery, discover_versions, min_version, max_version, **kwargs)
#     498             skip_discovery=skip_discovery,
#     499             allow_version_hack=allow_version_hack, **kwargs)
# --> 500         data = get_endpoint_data(discover_versions=discover_versions)
#     501         if (not data or not data.api_version) and not discover_versions:
#     502             # It's possible that no version was requested and the endpoint
#
# ~\anaconda3\lib\site-packages\keystoneauth1\identity\base.py in get_endpoint_data(self, session, service_type, interface, region_name, service_name, allow, allow_version_hack, discover_versions, skip_discovery, min_version, max_version, endpoint_override, **kwargs)
#     269                 interface = 'public'
#     270
# --> 271             service_catalog = self.get_access(session).service_catalog
#     272             project_id = self.get_project_id(session)
#     273             # NOTE(mordred): service_catalog.url_data_for raises if it can't
#
# ~\anaconda3\lib\site-packages\keystoneauth1\identity\base.py in get_access(self, session, **kwargs)
#     132         with self._lock:
#     133             if self._needs_reauthenticate():
# --> 134                 self.auth_ref = self.get_auth_ref(session)
#     135
#     136         return self.auth_ref
#
# ~\anaconda3\lib\site-packages\keystoneauth1\identity\generic\base.py in get_auth_ref(self, session, **kwargs)
#     206             self._plugin = self._do_create_plugin(session)
#     207
# --> 208         return self._plugin.get_auth_ref(session, **kwargs)
#     209
#     210     def get_cache_id_elements(self, _implemented=False):
#
# ~\anaconda3\lib\site-packages\keystoneauth1\identity\v3\base.py in get_auth_ref(self, session, **kwargs)
#     186
#     187         _logger.debug('Making authentication request to %s', token_url)
# --> 188         resp = session.post(token_url, json=body, headers=headers,
#     189                             authenticated=False, log=False, **rkwargs)
#     190
#
# ~\anaconda3\lib\site-packages\keystoneauth1\session.py in post(self, url, **kwargs)
#    1147
#    1148         """
# -> 1149         return self.request(url, 'POST', **kwargs)
#    1150
#    1151     def put(self, url, **kwargs):
#
# ~\anaconda3\lib\site-packages\keystoneauth1\session.py in request(self, url, method, json, original_ip, user_agent, redirect, authenticated, endpoint_filter, auth, requests_auth, raise_exc, allow_reauth, log, endpoint_override, connect_retries, logger, allow, client_name, client_version, microversion, microversion_service_type, status_code_retries, retriable_status_codes, rate_semaphore, global_request_id, connect_retry_delay, status_code_retry_delay, **kwargs)
#     984             logger.debug('Request returned failure status: %s',
#     985                          resp.status_code)
# --> 986             raise exceptions.from_response(resp, method, url)
#     987
#     988         if self._collect_timing:
#
# Unauthorized: The request you have made requires authentication. (HTTP 401) (Request-ID: req-b59c95cd-111d-4200-b8e4-cae1199ba2d6)

# %%
for flavor in conn.compute.flavors():
    print(flavor.to_dict())
# Out:
# Making authentication request to http://controller:5000/v3/auth/tokens
# Request returned failure status: 401
# ---------------------------------------------------------------------------
# Unauthorized                              Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15588\1314100513.py in <module>
# ----> 1 for flavor in conn.compute.flavors():
#       2     print(flavor.to_dict())
#
# ~\anaconda3\lib\site-packages\openstack\service_description.py in __get__(self, instance, owner)
#      85             return self
#      86         if self.service_type not in instance._proxies:
# ---> 87             proxy = self._make_proxy(instance)
#      88             if not isinstance(proxy, _ServiceDisabledProxyShim):
#      89                 # The keystone proxy has a method called get_endpoint
#
# ~\anaconda3\lib\site-packages\openstack\service_description.py in _make_proxy(self, instance)
#     260             **version_kwargs
#     261         )
# --> 262         found_version = temp_adapter.get_api_major_version()
#     263         if found_version is None:
#     264             region_name = instance.config.get_region_name(self.service_type)
#
# ~\anaconda3\lib\site-packages\keystoneauth1\adapter.py in get_api_major_version(self, auth, **kwargs)
#     352             kwargs['endpoint_override'] = self.endpoint_override
#     353
# --> 354         return self.session.get_api_major_version(auth or self.auth, **kwargs)
#     355
#     356     def invalidate(self, auth=None):
#
# ~\anaconda3\lib\site-packages\keystoneauth1\session.py in get_api_major_version(self, auth, **kwargs)
#    1274         """
#    1275         auth = self._auth_required(auth, 'determine endpoint URL')
# -> 1276         return auth.get_api_major_version(self, **kwargs)
#    1277
#    1278     def get_all_version_data(self, auth=None, interface='public',
#
# ~\anaconda3\lib\site-packages\keystoneauth1\identity\base.py in get_api_major_version(self, session, service_type, interface, region_name, service_name, version, allow, allow_version_hack, skip_discovery, discover_versions, min_version, max_version, **kwargs)
#     498             skip_discovery=skip_discovery,
#     499             allow_version_hack=allow_version_hack, **kwargs)
# --> 500         data = get_endpoint_data(discover_versions=discover_versions)
#     501         if (not data or not data.api_version) and not discover_versions:
#     502             # It's possible that no version was requested and the endpoint
#
# ~\anaconda3\lib\site-packages\keystoneauth1\identity\base.py in get_endpoint_data(self, session, service_type, interface, region_name, service_name, allow, allow_version_hack, discover_versions, skip_discovery, min_version, max_version, endpoint_override, **kwargs)
#     269                 interface = 'public'
#     270
# --> 271             service_catalog = self.get_access(session).service_catalog
#     272             project_id = self.get_project_id(session)
#     273             # NOTE(mordred): service_catalog.url_data_for raises if it can't
#
# ~\anaconda3\lib\site-packages\keystoneauth1\identity\base.py in get_access(self, session, **kwargs)
#     132         with self._lock:
#     133             if self._needs_reauthenticate():
# --> 134                 self.auth_ref = self.get_auth_ref(session)
#     135
#     136         return self.auth_ref
#
# ~\anaconda3\lib\site-packages\keystoneauth1\identity\generic\base.py in get_auth_ref(self, session, **kwargs)
#     206             self._plugin = self._do_create_plugin(session)
#     207
# --> 208         return self._plugin.get_auth_ref(session, **kwargs)
#     209
#     210     def get_cache_id_elements(self, _implemented=False):
#
# ~\anaconda3\lib\site-packages\keystoneauth1\identity\v3\base.py in get_auth_ref(self, session, **kwargs)
#     186
#     187         _logger.debug('Making authentication request to %s', token_url)
# --> 188         resp = session.post(token_url, json=body, headers=headers,
#     189                             authenticated=False, log=False, **rkwargs)
#     190
#
# ~\anaconda3\lib\site-packages\keystoneauth1\session.py in post(self, url, **kwargs)
#    1147
#    1148         """
# -> 1149         return self.request(url, 'POST', **kwargs)
#    1150
#    1151     def put(self, url, **kwargs):
#
# ~\anaconda3\lib\site-packages\keystoneauth1\session.py in request(self, url, method, json, original_ip, user_agent, redirect, authenticated, endpoint_filter, auth, requests_auth, raise_exc, allow_reauth, log, endpoint_override, connect_retries, logger, allow, client_name, client_version, microversion, microversion_service_type, status_code_retries, retriable_status_codes, rate_semaphore, global_request_id, connect_retry_delay, status_code_retry_delay, **kwargs)
#     984             logger.debug('Request returned failure status: %s',
#     985                          resp.status_code)
# --> 986             raise exceptions.from_response(resp, method, url)
#     987
#     988         if self._collect_timing:
#
# Unauthorized: The request you have made requires authentication. (HTTP 401) (Request-ID: req-a8612512-9c52-4721-8293-7184c335c8ab)

# %%
for endpoint in conn.identity.endpoints():
    print(endpoint)
# Out:
# Making authentication request to http://controller:5000/v3/auth/tokens
# Request returned failure status: 401
# ---------------------------------------------------------------------------
# Unauthorized                              Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15588\1578868276.py in <module>
# ----> 1 for endpoint in conn.identity.endpoints():
#       2     print(endpoint)
#
# ~\anaconda3\lib\site-packages\openstack\service_description.py in __get__(self, instance, owner)
#      85             return self
#      86         if self.service_type not in instance._proxies:
# ---> 87             proxy = self._make_proxy(instance)
#      88             if not isinstance(proxy, _ServiceDisabledProxyShim):
#      89                 # The keystone proxy has a method called get_endpoint
#
# ~\anaconda3\lib\site-packages\openstack\service_description.py in _make_proxy(self, instance)
#     260             **version_kwargs
#     261         )
# --> 262         found_version = temp_adapter.get_api_major_version()
#     263         if found_version is None:
#     264             region_name = instance.config.get_region_name(self.service_type)
#
# ~\anaconda3\lib\site-packages\keystoneauth1\adapter.py in get_api_major_version(self, auth, **kwargs)
#     352             kwargs['endpoint_override'] = self.endpoint_override
#     353
# --> 354         return self.session.get_api_major_version(auth or self.auth, **kwargs)
#     355
#     356     def invalidate(self, auth=None):
#
# ~\anaconda3\lib\site-packages\keystoneauth1\session.py in get_api_major_version(self, auth, **kwargs)
#    1274         """
#    1275         auth = self._auth_required(auth, 'determine endpoint URL')
# -> 1276         return auth.get_api_major_version(self, **kwargs)
#    1277
#    1278     def get_all_version_data(self, auth=None, interface='public',
#
# ~\anaconda3\lib\site-packages\keystoneauth1\identity\base.py in get_api_major_version(self, session, service_type, interface, region_name, service_name, version, allow, allow_version_hack, skip_discovery, discover_versions, min_version, max_version, **kwargs)
#     498             skip_discovery=skip_discovery,
#     499             allow_version_hack=allow_version_hack, **kwargs)
# --> 500         data = get_endpoint_data(discover_versions=discover_versions)
#     501         if (not data or not data.api_version) and not discover_versions:
#     502             # It's possible that no version was requested and the endpoint
#
# ~\anaconda3\lib\site-packages\keystoneauth1\identity\base.py in get_endpoint_data(self, session, service_type, interface, region_name, service_name, allow, allow_version_hack, discover_versions, skip_discovery, min_version, max_version, endpoint_override, **kwargs)
#     269                 interface = 'public'
#     270
# --> 271             service_catalog = self.get_access(session).service_catalog
#     272             project_id = self.get_project_id(session)
#     273             # NOTE(mordred): service_catalog.url_data_for raises if it can't
#
# ~\anaconda3\lib\site-packages\keystoneauth1\identity\base.py in get_access(self, session, **kwargs)
#     132         with self._lock:
#     133             if self._needs_reauthenticate():
# --> 134                 self.auth_ref = self.get_auth_ref(session)
#     135
#     136         return self.auth_ref
#
# ~\anaconda3\lib\site-packages\keystoneauth1\identity\generic\base.py in get_auth_ref(self, session, **kwargs)
#     206             self._plugin = self._do_create_plugin(session)
#     207
# --> 208         return self._plugin.get_auth_ref(session, **kwargs)
#     209
#     210     def get_cache_id_elements(self, _implemented=False):
#
# ~\anaconda3\lib\site-packages\keystoneauth1\identity\v3\base.py in get_auth_ref(self, session, **kwargs)
#     186
#     187         _logger.debug('Making authentication request to %s', token_url)
# --> 188         resp = session.post(token_url, json=body, headers=headers,
#     189                             authenticated=False, log=False, **rkwargs)
#     190
#
# ~\anaconda3\lib\site-packages\keystoneauth1\session.py in post(self, url, **kwargs)
#    1147
#    1148         """
# -> 1149         return self.request(url, 'POST', **kwargs)
#    1150
#    1151     def put(self, url, **kwargs):
#
# ~\anaconda3\lib\site-packages\keystoneauth1\session.py in request(self, url, method, json, original_ip, user_agent, redirect, authenticated, endpoint_filter, auth, requests_auth, raise_exc, allow_reauth, log, endpoint_override, connect_retries, logger, allow, client_name, client_version, microversion, microversion_service_type, status_code_retries, retriable_status_codes, rate_semaphore, global_request_id, connect_retry_delay, status_code_retry_delay, **kwargs)
#     984             logger.debug('Request returned failure status: %s',
#     985                          resp.status_code)
# --> 986             raise exceptions.from_response(resp, method, url)
#     987
#     988         if self._collect_timing:
#
# Unauthorized: The request you have made requires authentication. (HTTP 401) (Request-ID: req-209ae3f9-aba5-46cd-8995-181d3fdd8323)

# %%
for project in conn.identity.projects():
    print(project)
# Out:
# Making authentication request to http://controller:5000/v3/auth/tokens
# Request returned failure status: 401
# ---------------------------------------------------------------------------
# Unauthorized                              Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15588\64389301.py in <module>
# ----> 1 for project in conn.identity.projects():
#       2     print(project)
#
# ~\anaconda3\lib\site-packages\openstack\service_description.py in __get__(self, instance, owner)
#      85             return self
#      86         if self.service_type not in instance._proxies:
# ---> 87             proxy = self._make_proxy(instance)
#      88             if not isinstance(proxy, _ServiceDisabledProxyShim):
#      89                 # The keystone proxy has a method called get_endpoint
#
# ~\anaconda3\lib\site-packages\openstack\service_description.py in _make_proxy(self, instance)
#     260             **version_kwargs
#     261         )
# --> 262         found_version = temp_adapter.get_api_major_version()
#     263         if found_version is None:
#     264             region_name = instance.config.get_region_name(self.service_type)
#
# ~\anaconda3\lib\site-packages\keystoneauth1\adapter.py in get_api_major_version(self, auth, **kwargs)
#     352             kwargs['endpoint_override'] = self.endpoint_override
#     353
# --> 354         return self.session.get_api_major_version(auth or self.auth, **kwargs)
#     355
#     356     def invalidate(self, auth=None):
#
# ~\anaconda3\lib\site-packages\keystoneauth1\session.py in get_api_major_version(self, auth, **kwargs)
#    1274         """
#    1275         auth = self._auth_required(auth, 'determine endpoint URL')
# -> 1276         return auth.get_api_major_version(self, **kwargs)
#    1277
#    1278     def get_all_version_data(self, auth=None, interface='public',
#
# ~\anaconda3\lib\site-packages\keystoneauth1\identity\base.py in get_api_major_version(self, session, service_type, interface, region_name, service_name, version, allow, allow_version_hack, skip_discovery, discover_versions, min_version, max_version, **kwargs)
#     498             skip_discovery=skip_discovery,
#     499             allow_version_hack=allow_version_hack, **kwargs)
# --> 500         data = get_endpoint_data(discover_versions=discover_versions)
#     501         if (not data or not data.api_version) and not discover_versions:
#     502             # It's possible that no version was requested and the endpoint
#
# ~\anaconda3\lib\site-packages\keystoneauth1\identity\base.py in get_endpoint_data(self, session, service_type, interface, region_name, service_name, allow, allow_version_hack, discover_versions, skip_discovery, min_version, max_version, endpoint_override, **kwargs)
#     269                 interface = 'public'
#     270
# --> 271             service_catalog = self.get_access(session).service_catalog
#     272             project_id = self.get_project_id(session)
#     273             # NOTE(mordred): service_catalog.url_data_for raises if it can't
#
# ~\anaconda3\lib\site-packages\keystoneauth1\identity\base.py in get_access(self, session, **kwargs)
#     132         with self._lock:
#     133             if self._needs_reauthenticate():
# --> 134                 self.auth_ref = self.get_auth_ref(session)
#     135
#     136         return self.auth_ref
#
# ~\anaconda3\lib\site-packages\keystoneauth1\identity\generic\base.py in get_auth_ref(self, session, **kwargs)
#     206             self._plugin = self._do_create_plugin(session)
#     207
# --> 208         return self._plugin.get_auth_ref(session, **kwargs)
#     209
#     210     def get_cache_id_elements(self, _implemented=False):
#
# ~\anaconda3\lib\site-packages\keystoneauth1\identity\v3\base.py in get_auth_ref(self, session, **kwargs)
#     186
#     187         _logger.debug('Making authentication request to %s', token_url)
# --> 188         resp = session.post(token_url, json=body, headers=headers,
#     189                             authenticated=False, log=False, **rkwargs)
#     190
#
# ~\anaconda3\lib\site-packages\keystoneauth1\session.py in post(self, url, **kwargs)
#    1147
#    1148         """
# -> 1149         return self.request(url, 'POST', **kwargs)
#    1150
#    1151     def put(self, url, **kwargs):
#
# ~\anaconda3\lib\site-packages\keystoneauth1\session.py in request(self, url, method, json, original_ip, user_agent, redirect, authenticated, endpoint_filter, auth, requests_auth, raise_exc, allow_reauth, log, endpoint_override, connect_retries, logger, allow, client_name, client_version, microversion, microversion_service_type, status_code_retries, retriable_status_codes, rate_semaphore, global_request_id, connect_retry_delay, status_code_retry_delay, **kwargs)
#     984             logger.debug('Request returned failure status: %s',
#     985                          resp.status_code)
# --> 986             raise exceptions.from_response(resp, method, url)
#     987
#     988         if self._collect_timing:
#
# Unauthorized: The request you have made requires authentication. (HTTP 401) (Request-ID: req-9d7a9911-b395-47c7-a0fd-73ca52de667a)

# %%
for user in conn.identity.users():
    print(user)
# Out:
# Making authentication request to http://controller:5000/v3/auth/tokens
# Request returned failure status: 401
# ---------------------------------------------------------------------------
# Unauthorized                              Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15588\3040360000.py in <module>
# ----> 1 for user in conn.identity.users():
#       2     print(user)
#
# ~\anaconda3\lib\site-packages\openstack\service_description.py in __get__(self, instance, owner)
#      85             return self
#      86         if self.service_type not in instance._proxies:
# ---> 87             proxy = self._make_proxy(instance)
#      88             if not isinstance(proxy, _ServiceDisabledProxyShim):
#      89                 # The keystone proxy has a method called get_endpoint
#
# ~\anaconda3\lib\site-packages\openstack\service_description.py in _make_proxy(self, instance)
#     260             **version_kwargs
#     261         )
# --> 262         found_version = temp_adapter.get_api_major_version()
#     263         if found_version is None:
#     264             region_name = instance.config.get_region_name(self.service_type)
#
# ~\anaconda3\lib\site-packages\keystoneauth1\adapter.py in get_api_major_version(self, auth, **kwargs)
#     352             kwargs['endpoint_override'] = self.endpoint_override
#     353
# --> 354         return self.session.get_api_major_version(auth or self.auth, **kwargs)
#     355
#     356     def invalidate(self, auth=None):
#
# ~\anaconda3\lib\site-packages\keystoneauth1\session.py in get_api_major_version(self, auth, **kwargs)
#    1274         """
#    1275         auth = self._auth_required(auth, 'determine endpoint URL')
# -> 1276         return auth.get_api_major_version(self, **kwargs)
#    1277
#    1278     def get_all_version_data(self, auth=None, interface='public',
#
# ~\anaconda3\lib\site-packages\keystoneauth1\identity\base.py in get_api_major_version(self, session, service_type, interface, region_name, service_name, version, allow, allow_version_hack, skip_discovery, discover_versions, min_version, max_version, **kwargs)
#     498             skip_discovery=skip_discovery,
#     499             allow_version_hack=allow_version_hack, **kwargs)
# --> 500         data = get_endpoint_data(discover_versions=discover_versions)
#     501         if (not data or not data.api_version) and not discover_versions:
#     502             # It's possible that no version was requested and the endpoint
#
# ~\anaconda3\lib\site-packages\keystoneauth1\identity\base.py in get_endpoint_data(self, session, service_type, interface, region_name, service_name, allow, allow_version_hack, discover_versions, skip_discovery, min_version, max_version, endpoint_override, **kwargs)
#     269                 interface = 'public'
#     270
# --> 271             service_catalog = self.get_access(session).service_catalog
#     272             project_id = self.get_project_id(session)
#     273             # NOTE(mordred): service_catalog.url_data_for raises if it can't
#
# ~\anaconda3\lib\site-packages\keystoneauth1\identity\base.py in get_access(self, session, **kwargs)
#     132         with self._lock:
#     133             if self._needs_reauthenticate():
# --> 134                 self.auth_ref = self.get_auth_ref(session)
#     135
#     136         return self.auth_ref
#
# ~\anaconda3\lib\site-packages\keystoneauth1\identity\generic\base.py in get_auth_ref(self, session, **kwargs)
#     206             self._plugin = self._do_create_plugin(session)
#     207
# --> 208         return self._plugin.get_auth_ref(session, **kwargs)
#     209
#     210     def get_cache_id_elements(self, _implemented=False):
#
# ~\anaconda3\lib\site-packages\keystoneauth1\identity\v3\base.py in get_auth_ref(self, session, **kwargs)
#     186
#     187         _logger.debug('Making authentication request to %s', token_url)
# --> 188         resp = session.post(token_url, json=body, headers=headers,
#     189                             authenticated=False, log=False, **rkwargs)
#     190
#
# ~\anaconda3\lib\site-packages\keystoneauth1\session.py in post(self, url, **kwargs)
#    1147
#    1148         """
# -> 1149         return self.request(url, 'POST', **kwargs)
#    1150
#    1151     def put(self, url, **kwargs):
#
# ~\anaconda3\lib\site-packages\keystoneauth1\session.py in request(self, url, method, json, original_ip, user_agent, redirect, authenticated, endpoint_filter, auth, requests_auth, raise_exc, allow_reauth, log, endpoint_override, connect_retries, logger, allow, client_name, client_version, microversion, microversion_service_type, status_code_retries, retriable_status_codes, rate_semaphore, global_request_id, connect_retry_delay, status_code_retry_delay, **kwargs)
#     984             logger.debug('Request returned failure status: %s',
#     985                          resp.status_code)
# --> 986             raise exceptions.from_response(resp, method, url)
#     987
#     988         if self._collect_timing:
#
# Unauthorized: The request you have made requires authentication. (HTTP 401) (Request-ID: req-d104b193-2dc3-4ab6-9ede-d055d5976402)
